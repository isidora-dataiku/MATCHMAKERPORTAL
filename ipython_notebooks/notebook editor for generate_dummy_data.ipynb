# %%
# -*- coding: utf-8 -*-
"""
Recipe: generate_dummy_data
Generates 50 dummy Dutch candidate profiles and 30 Dutch job postings.
No inputs — creates candidates_raw and job_postings_raw from scratch.
"""
import dataiku
import pandas as pd
import numpy as np
import random
from dataiku import pandasutils as pdu

random.seed(42)

# ---------------------------------------------------------------------------
# CANDIDATES DATA
# ---------------------------------------------------------------------------

GEMEENTEN = [
    "Amsterdam", "Rotterdam", "Utrecht", "Den Haag", "Eindhoven",
    "Tilburg", "Groningen", "Almere", "Breda", "Nijmegen",
    "Haarlem", "Arnhem", "Zaandam", "Amersfoort", "Leeuwarden",
    "Maastricht", "Dordrecht", "Leiden", "Zwolle", "Ede",
]

KANDIDATEN_PROFIELEN = [
    # LOGISTIEK (6 profielen)
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Logistiek en transport",
        "werkervaring_jaren": 5.0, "laatste_functie": "Magazijnmedewerker",
        "vaardigheden_raw": "orderpicken, WMS, vorkheftruck, palletiseren, voorraadbeheer, scannen",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Logistiek en transport",
        "werkervaring_jaren": 8.0, "laatste_functie": "Orderpicker",
        "vaardigheden_raw": "orderpicken, reachtruck, elektrische palletwagen, WMS, veiligheid",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Logistiek",
        "werkervaring_jaren": 12.0, "laatste_functie": "Teamleider Logistiek",
        "vaardigheden_raw": "teamleiding, planning, WMS, SAP, voorraadbeheer, magazijnbeheer, rapportage",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "vmbo", "opleiding_richting": "Techniek",
        "werkervaring_jaren": 3.0, "laatste_functie": "Magazijnmedewerker",
        "vaardigheden_raw": "orderpicken, palletiseren, laadklep, tillen, veiligheid",
        "uitkering_type": "Bijstand", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Logistiek en supply chain management",
        "werkervaring_jaren": 6.0, "laatste_functie": "Logistiek coordinator",
        "vaardigheden_raw": "supply chain, inkoop, SAP, Excel, planning, leveranciersbeheer, Incoterms",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Chauffeur goederenvervoer",
        "werkervaring_jaren": 10.0, "laatste_functie": "Vrachtwagenchauffeur",
        "vaardigheden_raw": "rijbewijs CE, digitale tachograaf, ADR-basis, routeplanning, klantencontact",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    # ZORG (6 profielen)
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Verzorgende IG",
        "werkervaring_jaren": 7.0, "laatste_functie": "Verzorgende IG",
        "vaardigheden_raw": "persoonlijke verzorging, medicatiebeheer, rapportage, ECD, ouderenzorg, empathie",
        "uitkering_type": "WW", "beschikbaarheid": "parttime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Verpleegkunde",
        "werkervaring_jaren": 9.0, "laatste_functie": "Verpleegkundige",
        "vaardigheden_raw": "patiëntenzorg, medicatietoediening, infuustechniek, ECD, teamwork, communicatie",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Helpende zorg en welzijn",
        "werkervaring_jaren": 2.0, "laatste_functie": "Helpende Zorg",
        "vaardigheden_raw": "huishoudelijke hulp, persoonlijke verzorging, dagactiviteiten, rapportage",
        "uitkering_type": "Bijstand", "beschikbaarheid": "parttime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Sociaal werk",
        "werkervaring_jaren": 4.0, "laatste_functie": "Begeleider dagbesteding",
        "vaardigheden_raw": "begeleiding, gedragsproblemen, rapportage, teamwork, activiteitenbegeleiding",
        "uitkering_type": "WW", "beschikbaarheid": "parttime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Doktersassistent",
        "werkervaring_jaren": 5.0, "laatste_functie": "Doktersassistent",
        "vaardigheden_raw": "triage, medische administratie, HIS, bloedafname, patiëntcontact, receptie",
        "uitkering_type": "WW", "beschikbaarheid": "parttime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Fysiotherapie",
        "werkervaring_jaren": 8.0, "laatste_functie": "Fysiotherapeut",
        "vaardigheden_raw": "revalidatie, manuele therapie, dry needling, EPD, patiënteducatie, sport",
        "uitkering_type": "WW", "beschikbaarheid": "parttime",
    },
    # ICT (7 profielen)
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Informatica",
        "werkervaring_jaren": 6.0, "laatste_functie": "Software Developer",
        "vaardigheden_raw": "Python, Java, SQL, Git, Agile, REST API, Docker, Linux",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Bedrijfsinformatica",
        "werkervaring_jaren": 4.0, "laatste_functie": "ICT Beheerder",
        "vaardigheden_raw": "Windows Server, Active Directory, Azure, netwerkbeheer, helpdesk, PowerShell",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "wo", "opleiding_richting": "Informatiekunde",
        "werkervaring_jaren": 8.0, "laatste_functie": "Data Analist",
        "vaardigheden_raw": "Python, SQL, Power BI, Tableau, data visualisatie, statistiek, Excel, machine learning",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "ICT medewerker",
        "werkervaring_jaren": 3.0, "laatste_functie": "Helpdesk Medewerker",
        "vaardigheden_raw": "Servicedesk, Windows 10, Office 365, ticketsysteem, klantgerichtheid, netwerk basis",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Technische informatica",
        "werkervaring_jaren": 5.0, "laatste_functie": "DevOps Engineer",
        "vaardigheden_raw": "CI/CD, Docker, Kubernetes, Jenkins, Azure DevOps, Python, Linux, monitoring",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "wo", "opleiding_richting": "Kunstmatige intelligentie",
        "werkervaring_jaren": 3.0, "laatste_functie": "Machine Learning Engineer",
        "vaardigheden_raw": "Python, TensorFlow, PyTorch, MLOps, SQL, cloud, experimenteren, Git",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Communicatie en multimedia design",
        "werkervaring_jaren": 4.0, "laatste_functie": "UX Designer",
        "vaardigheden_raw": "Figma, gebruikersonderzoek, wireframes, prototyping, HTML, CSS, klantinzichten",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    # ADMINISTRATIE (7 profielen)
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Administratie",
        "werkervaring_jaren": 8.0, "laatste_functie": "Administratief medewerker",
        "vaardigheden_raw": "Excel, Word, debiteurenbeheer, factuurverwerking, Exact, archiveren, klantenservice",
        "uitkering_type": "WW", "beschikbaarheid": "parttime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Bedrijfseconomie",
        "werkervaring_jaren": 10.0, "laatste_functie": "Controller",
        "vaardigheden_raw": "financiële rapportage, budgettering, Excel, SAP, forecasting, management informatie",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Secretarieel",
        "werkervaring_jaren": 6.0, "laatste_functie": "Managementassistente",
        "vaardigheden_raw": "agenda- en reisbeheer, notulen, correspondentie, Office 365, representatief",
        "uitkering_type": "WW", "beschikbaarheid": "parttime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "HRM",
        "werkervaring_jaren": 5.0, "laatste_functie": "HR medewerker",
        "vaardigheden_raw": "salarisadministratie, werving, Afas, HR-beleid, gesprekken voeren, arbeidsrecht basis",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Juridisch medewerker",
        "werkervaring_jaren": 4.0, "laatste_functie": "Juridisch administratief medewerker",
        "vaardigheden_raw": "juridische documenten, archiveren, correspondentie, Word, dossierbeheer, AVG",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "wo", "opleiding_richting": "Economie",
        "werkervaring_jaren": 12.0, "laatste_functie": "Financieel manager",
        "vaardigheden_raw": "consolidatie, jaarrekening, IFRS, SAP, budgettering, management rapportage, leidinggeven",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Commerciële administratie",
        "werkervaring_jaren": 3.0, "laatste_functie": "Klantservicemedewerker",
        "vaardigheden_raw": "telefonie, e-mail, CRM, klachtenafhandeling, administratie, SAP",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    # RETAIL (5 profielen)
    {
        "opleiding_niveau": "vmbo", "opleiding_richting": "Detailhandel",
        "werkervaring_jaren": 4.0, "laatste_functie": "Verkoopmedewerker",
        "vaardigheden_raw": "kassa, klantenservice, schappenplan, voorraadbeheer, upselling",
        "uitkering_type": "WW", "beschikbaarheid": "parttime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Retail management",
        "werkervaring_jaren": 7.0, "laatste_functie": "Filiaalmanager",
        "vaardigheden_raw": "personeelsplanning, omzetverantwoordelijkheid, klanttevredenheid, inkoop, kassabeheer",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "vmbo", "opleiding_richting": "Horeca",
        "werkervaring_jaren": 3.0, "laatste_functie": "Servicemedewerker horeca",
        "vaardigheden_raw": "bediening, koffie, hygiëne, klantgerichtheid, kassa, teamwork",
        "uitkering_type": "Bijstand", "beschikbaarheid": "beide",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Commercie",
        "werkervaring_jaren": 5.0, "laatste_functie": "Accountmanager binnendienst",
        "vaardigheden_raw": "CRM, offertes, klantencontact, Excel, telefonische verkoop, relatiebeheer",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Marketing en communicatie",
        "werkervaring_jaren": 5.0, "laatste_functie": "Marketing medewerker",
        "vaardigheden_raw": "social media, content creatie, Google Analytics, e-mailmarketing, Canva, campagnes",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    # BOUW / TECHNIEK (6 profielen)
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Bouwkunde",
        "werkervaring_jaren": 9.0, "laatste_functie": "Uitvoerder bouw",
        "vaardigheden_raw": "werkvoorbereiding, VCA, AutoCAD, planning, onderaannemers, kwaliteitscontrole",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "vmbo", "opleiding_richting": "Elektrotechniek",
        "werkervaring_jaren": 6.0, "laatste_functie": "Elektromonteur",
        "vaardigheden_raw": "elektrische installaties, bekabeling, meterkast, VCA, NEN 3140, storingsdiagnose",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Installatietechniek",
        "werkervaring_jaren": 4.0, "laatste_functie": "Loodgieter",
        "vaardigheden_raw": "sanitair, cv-installatie, lekdetectie, VCA, KIWA, montage, reparatie",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Werktuigbouwkunde",
        "werkervaring_jaren": 11.0, "laatste_functie": "Onderhoudsmonteur industrie",
        "vaardigheden_raw": "preventief onderhoud, storingsanalyse, pneumatiek, hydrauliek, lassen MIG/MAG, VCA",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Civiele techniek",
        "werkervaring_jaren": 7.0, "laatste_functie": "Projectleider infra",
        "vaardigheden_raw": "projectmanagement, aanbesteding, AutoCAD, RAW-bestek, stakeholdermanagement, planning",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Schilder/afwerking",
        "werkervaring_jaren": 8.0, "laatste_functie": "Schilder",
        "vaardigheden_raw": "schilderen, pleisteren, behangen, spuittechnieken, VCA, kleuradvies",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    # OVERIG (6 profielen)
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Pedagogiek",
        "werkervaring_jaren": 6.0, "laatste_functie": "Groepsleider kinderopvang",
        "vaardigheden_raw": "kinderzorg, ontwikkelingspsychologie, BKR, VVE, oudercommunicatie, teamwork",
        "uitkering_type": "WW", "beschikbaarheid": "parttime",
    },
    {
        "opleiding_niveau": "wo", "opleiding_richting": "Psychologie",
        "werkervaring_jaren": 7.0, "laatste_functie": "Loopbaancoach",
        "vaardigheden_raw": "coaching, gesprekstechnieken, assessments, arbeidsmarktkennis, rapportage, motiveren",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Bestuurskunde",
        "werkervaring_jaren": 9.0, "laatste_functie": "Beleidsmedewerker gemeente",
        "vaardigheden_raw": "beleidsanalyse, rapportage, vergaderen, stakeholders, Excel, subsidies, wetgeving",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Facility management",
        "werkervaring_jaren": 5.0, "laatste_functie": "Facilitair medewerker",
        "vaardigheden_raw": "huisvestingsbeheer, catering, schoonmaakcoördinatie, contractbeheer, Excel, FMIS",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Toegepaste psychologie",
        "werkervaring_jaren": 6.0, "laatste_functie": "Re-integratieconsulent",
        "vaardigheden_raw": "intake, trajectbegeleiding, motivational interviewing, administratie, netwerken, rapportage",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "vmbo", "opleiding_richting": "Groen",
        "werkervaring_jaren": 5.0, "laatste_functie": "Groenmedewerker",
        "vaardigheden_raw": "maaien, snoeien, plantkennis, rijbewijs B, buitenwerk, VCA basis",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    # EXTRA PROFIELEN VOOR 50 TOTAAL (7 extra)
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Logistiek",
        "werkervaring_jaren": 4.0, "laatste_functie": "Expeditiemedewerker",
        "vaardigheden_raw": "douanedocumenten, transportplanning, Incoterms, SAP, klantencontact",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "vmbo", "opleiding_richting": "Transport en logistiek",
        "werkervaring_jaren": 2.0, "laatste_functie": "Pakketbezorger",
        "vaardigheden_raw": "bezorging, scanapparatuur, klantencontact, rijbewijs B, routeplanning",
        "uitkering_type": "Bijstand", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Tandartsassistent",
        "werkervaring_jaren": 5.0, "laatste_functie": "Tandartsassistent",
        "vaardigheden_raw": "assistence bij behandeling, sterilisatie, patiëntenbegeleiding, röntgen, administratie",
        "uitkering_type": "WW", "beschikbaarheid": "parttime",
    },
    {
        "opleiding_niveau": "vmbo", "opleiding_richting": "Handel",
        "werkervaring_jaren": 6.0, "laatste_functie": "Medewerker klantenservice",
        "vaardigheden_raw": "klantgerichtheid, telefonie, e-mail, CRM basis, klachtenbehandeling, geduld",
        "uitkering_type": "WW", "beschikbaarheid": "parttime",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Sport en bewegen",
        "werkervaring_jaren": 4.0, "laatste_functie": "Sportinstructeur",
        "vaardigheden_raw": "fitness instructie, groepslessen, EHBO, klantgerichtheid, bootcamp, voeding basis",
        "uitkering_type": "WW", "beschikbaarheid": "beide",
    },
    {
        "opleiding_niveau": "mbo", "opleiding_richting": "Voeding",
        "werkervaring_jaren": 3.0, "laatste_functie": "Keukenmedewerker",
        "vaardigheden_raw": "hygiëne, HACCP, koken, voedselveiligheid, teamwork, efficiëntie",
        "uitkering_type": "Bijstand", "beschikbaarheid": "fulltime",
    },
    {
        "opleiding_niveau": "hbo", "opleiding_richting": "Communicatie",
        "werkervaring_jaren": 4.0, "laatste_functie": "Communicatiemedewerker",
        "vaardigheden_raw": "copywriting, social media, persberichten, Canva, interne communicatie, Adobe",
        "uitkering_type": "WW", "beschikbaarheid": "fulltime",
    },
]

TALEN_OPTIES = [
    "Nederlands",
    "Nederlands, Engels",
    "Nederlands, Engels, Duits",
    "Nederlands, Engels, Frans",
    "Nederlands, Turks",
    "Nederlands, Arabisch",
    "Nederlands, Pools",
]

GEBOORTEJAREN = list(range(1965, 2001))
MOBILITEIT = [10, 15, 20, 25, 30, 40, 50]


def maak_kandidaten():
    kandidaten = []
    profielen = KANDIDATEN_PROFIELEN[:50]
    for i, profiel in enumerate(profielen, start=1):
        kandidaat = {
            "candidate_id": f"C-{i:03d}",
            "geboortejaar": random.choice(GEBOORTEJAREN),
            "gemeente": random.choice(GEMEENTEN),
            "opleiding_niveau": profiel["opleiding_niveau"],
            "opleiding_richting": profiel["opleiding_richting"],
            "werkervaring_jaren": profiel["werkervaring_jaren"],
            "laatste_functie": profiel["laatste_functie"],
            "vaardigheden_raw": profiel["vaardigheden_raw"],
            "talen": random.choice(TALEN_OPTIES),
            "beschikbaarheid": profiel["beschikbaarheid"],
            "mobiliteitskm": random.choice(MOBILITEIT),
            "uitkering_type": profiel["uitkering_type"],
        }
        kandidaten.append(kandidaat)
    return kandidaten


# ---------------------------------------------------------------------------
# VACATURES DATA
# ---------------------------------------------------------------------------

VACATURES = [
    # LOGISTIEK (5)
    {
        "titel": "Magazijnmedewerker", "bedrijf_naam": "Jumbo Distributiecentrum",
        "bedrijf_sector": "Logistiek", "gemeente": "Veghel", "contract_type": "vast",
        "uren_per_week_min": 32, "uren_per_week_max": 40,
        "vereiste_opleiding": "vmbo", "vereiste_ervaring_jaren": 1,
        "vereiste_vaardigheden_raw": "orderpicken, WMS, vorkheftruck, scannen, palletiseren",
        "omschrijving": "Als magazijnmedewerker bij Jumbo ben je verantwoordelijk voor het efficiënt verwerken van inkomende en uitgaande goederen. Je werkt met ons WMS en zorgt voor een correcte opslag en uitgifte van producten. Je hebt ervaring met orderpicken en bent niet bang voor fysiek werk. Veiligheidsbewustzijn staat bij ons hoog in het vaandel.",
    },
    {
        "titel": "Teamleider Logistiek", "bedrijf_naam": "PostNL Sorteercentrum",
        "bedrijf_sector": "Logistiek", "gemeente": "Amsterdam", "contract_type": "vast",
        "uren_per_week_min": 36, "uren_per_week_max": 40,
        "vereiste_opleiding": "mbo", "vereiste_ervaring_jaren": 5,
        "vereiste_vaardigheden_raw": "teamleiding, planning, WMS, rapportage, voorraadbeheer, magazijnbeheer",
        "omschrijving": "Je leidt een team van 15 magazijnmedewerkers en bent verantwoordelijk voor de dagelijkse operatie. Je maakt planningen, bewaakt KPI's en rapporteert aan de operationeel manager. Je hebt minimaal 5 jaar logistieke ervaring en bij voorkeur leidinggevende ervaring. SAP-kennis is een pré.",
    },
    {
        "titel": "Logistiek Coordinator", "bedrijf_naam": "Rhenus Logistics",
        "bedrijf_sector": "Logistiek", "gemeente": "Rotterdam", "contract_type": "vast",
        "uren_per_week_min": 40, "uren_per_week_max": 40,
        "vereiste_opleiding": "hbo", "vereiste_ervaring_jaren": 3,
        "vereiste_vaardigheden_raw": "supply chain, SAP, Excel, planning, leveranciersbeheer, Incoterms",
        "omschrijving": "In de rol van logistiek coordinator ben je de spil tussen inkoop, productie en distributie. Je bewaakt de goederenstromen en optimaliseert de supply chain. Je hebt een afgeronde hbo-opleiding in logistiek en minimaal 3 jaar relevante ervaring. Kennis van SAP en Incoterms is vereist.",
    },
    {
        "titel": "Chauffeur Distributie", "bedrijf_naam": "DHL Express Nederland",
        "bedrijf_sector": "Logistiek", "gemeente": "Utrecht", "contract_type": "vast",
        "uren_per_week_min": 36, "uren_per_week_max": 40,
        "vereiste_opleiding": "vmbo", "vereiste_ervaring_jaren": 2,
        "vereiste_vaardigheden_raw": "rijbewijs CE, digitale tachograaf, routeplanning, klantencontact, veiligheid",
        "omschrijving": "Als chauffeur distributie rijd je dagelijkse ritten door heel Nederland voor het bezorgen van pakketten en pallets. Je beschikt over een geldig rijbewijs CE en kennis van de digitale tachograaf. Klantgerichtheid en stiptheid zijn voor jou vanzelfsprekend. ADR-certificering is een pré.",
    },
    {
        "titel": "Orderpicker Nachtdienst", "bedrijf_naam": "Bol.com Distributiecentrum",
        "bedrijf_sector": "Logistiek", "gemeente": "Utrecht", "contract_type": "tijdelijk",
        "uren_per_week_min": 32, "uren_per_week_max": 40,
        "vereiste_opleiding": "vmbo", "vereiste_ervaring_jaren": 0,
        "vereiste_vaardigheden_raw": "orderpicken, scannen, palletiseren, veiligheid, teamwork",
        "omschrijving": "Bol.com zoekt orderpickers voor de nachtdienst in haar distributiecentrum in Utrecht. Je verzamelt bestellingen met behulp van scanapparatuur en zorgt dat paketten klaar staan voor verzending. Geen ervaring nodig, wij leren je alles. Bereidheid om in nachtdiensten te werken is wel vereist.",
    },
    # ZORG (5)
    {
        "titel": "Verzorgende IG", "bedrijf_naam": "Zorggroep De Waarden",
        "bedrijf_sector": "Zorg", "gemeente": "Nijmegen", "contract_type": "vast",
        "uren_per_week_min": 24, "uren_per_week_max": 32,
        "vereiste_opleiding": "mbo", "vereiste_ervaring_jaren": 2,
        "vereiste_vaardigheden_raw": "persoonlijke verzorging, medicatiebeheer, ECD, rapportage, ouderenzorg",
        "omschrijving": "Wij zoeken een gediplomeerde Verzorgende IG voor onze woonzorglocatie in Nijmegen. Je biedt persoonlijke verzorging en begeleiding aan ouderen met complexe zorgvragen. Je werkt met ons elektronisch cliëntendossier en stelt zorgplannen op. Goede communicatieve vaardigheden en empathie zijn onmisbaar.",
    },
    {
        "titel": "Verpleegkundige Geriatrie", "bedrijf_naam": "Radboud UMC",
        "bedrijf_sector": "Zorg", "gemeente": "Nijmegen", "contract_type": "vast",
        "uren_per_week_min": 32, "uren_per_week_max": 36,
        "vereiste_opleiding": "hbo", "vereiste_ervaring_jaren": 2,
        "vereiste_vaardigheden_raw": "patiëntenzorg, medicatietoediening, infuustechniek, ECD, communicatie, teamwork",
        "omschrijving": "Het Radboud UMC zoekt een verpleegkundige voor de afdeling geriatrie. Je levert directe patiëntenzorg, verzorgt medicatietoediening en werkt nauw samen met artsen en paramedici. Je beschikt over een BIG-registratie als verpleegkundige en hebt affiniteit met ouderenzorg.",
    },
    {
        "titel": "Medewerker Dagbesteding", "bedrijf_naam": "GGZ Oost Brabant",
        "bedrijf_sector": "Zorg", "gemeente": "Eindhoven", "contract_type": "tijdelijk",
        "uren_per_week_min": 20, "uren_per_week_max": 28,
        "vereiste_opleiding": "mbo", "vereiste_ervaring_jaren": 1,
        "vereiste_vaardigheden_raw": "begeleiding, activiteitenbegeleiding, rapportage, teamwork, empathie",
        "omschrijving": "Voor onze dagbestedingslocatie zoeken wij een enthousiaste begeleider die samen met cliënten zinvolle activiteiten onderneemt. Je begeleidt mensen met psychiatrische problematiek bij werkgerelateerde en creatieve activiteiten. MBO-niveau zorg of welzijn is vereist.",
    },
    {
        "titel": "Doktersassistent Huisartsenpraktijk", "bedrijf_naam": "Huisartsenpraktijk Centrum",
        "bedrijf_sector": "Zorg", "gemeente": "Haarlem", "contract_type": "vast",
        "uren_per_week_min": 24, "uren_per_week_max": 32,
        "vereiste_opleiding": "mbo", "vereiste_ervaring_jaren": 1,
        "vereiste_vaardigheden_raw": "triage, medische administratie, HIS, patiëntcontact, receptie, bloedafname",
        "omschrijving": "Onze drukke huisartsenpraktijk zoekt een doktersassistent voor 24-32 uur per week. Je voert telefonische triage uit, plant afspraken in en assisteert bij kleine medische handelingen. Je werkt met het huisartsinformatiesysteem en bent het eerste aanspreekpunt voor patiënten.",
    },
    {
        "titel": "Fysiotherapeut", "bedrijf_naam": "Fysiotherapie Plus",
        "bedrijf_sector": "Zorg", "gemeente": "Amsterdam", "contract_type": "vast",
        "uren_per_week_min": 24, "uren_per_week_max": 36,
        "vereiste_opleiding": "hbo", "vereiste_ervaring_jaren": 2,
        "vereiste_vaardigheden_raw": "revalidatie, manuele therapie, patiënteducatie, EPD, sport",
        "omschrijving": "Fysiotherapie Plus zoekt een enthousiaste fysiotherapeut voor haar groeiende praktijk in Amsterdam. Je behandelt patiënten met een breed scala aan klachten, van sportblessures tot revalidatie na operaties. Je bent BIG-geregistreerd en hebt minimaal 2 jaar werkervaring.",
    },
    # ICT (5)
    {
        "titel": "Python Developer", "bedrijf_naam": "Sogeti Nederland",
        "bedrijf_sector": "ICT", "gemeente": "Utrecht", "contract_type": "vast",
        "uren_per_week_min": 36, "uren_per_week_max": 40,
        "vereiste_opleiding": "hbo", "vereiste_ervaring_jaren": 3,
        "vereiste_vaardigheden_raw": "Python, SQL, Git, REST API, Docker, Agile, Linux",
        "omschrijving": "Sogeti zoekt een ervaren Python Developer voor haar data engineering team. Je ontwikkelt en onderhoudt datapipelines en API's voor klanten in de publieke sector. Je werkt in een Agile team en hebt minimaal 3 jaar Python-ervaring. Kennis van Docker en Azure is een sterke pré.",
    },
    {
        "titel": "ICT Beheerder", "bedrijf_naam": "Gemeente Rotterdam",
        "bedrijf_sector": "ICT", "gemeente": "Rotterdam", "contract_type": "vast",
        "uren_per_week_min": 36, "uren_per_week_max": 40,
        "vereiste_opleiding": "hbo", "vereiste_ervaring_jaren": 2,
        "vereiste_vaardigheden_raw": "Windows Server, Active Directory, Azure, netwerkbeheer, helpdesk, PowerShell",
        "omschrijving": "De gemeente Rotterdam zoekt een ICT Beheerder voor het beheer van haar IT-infrastructuur. Je beheert servers, Active Directory en Azure-omgevingen en lost technische incidenten op. Je hebt minimaal 2 jaar ervaring met Windows Server en Azure. ITIL-certificering is een pré.",
    },
    {
        "titel": "Data Analist", "bedrijf_naam": "ING Nederland",
        "bedrijf_sector": "ICT", "gemeente": "Amsterdam", "contract_type": "vast",
        "uren_per_week_min": 36, "uren_per_week_max": 40,
        "vereiste_opleiding": "hbo", "vereiste_ervaring_jaren": 3,
        "vereiste_vaardigheden_raw": "Python, SQL, Power BI, data visualisatie, statistiek, Excel",
        "omschrijving": "ING zoekt een Data Analist om inzichten te genereren uit klant- en transactiedata. Je ontwikkelt dashboards in Power BI en analyseert grote datasets met Python en SQL. Je werkt samen met business stakeholders om datavragen te vertalen naar bruikbare inzichten.",
    },
    {
        "titel": "Servicedesk Medewerker ICT", "bedrijf_naam": "Capgemini Nederland",
        "bedrijf_sector": "ICT", "gemeente": "Amsterdam", "contract_type": "tijdelijk",
        "uren_per_week_min": 32, "uren_per_week_max": 40,
        "vereiste_opleiding": "mbo", "vereiste_ervaring_jaren": 1,
        "vereiste_vaardigheden_raw": "Servicedesk, Windows 10, Office 365, ticketsysteem, klantgerichtheid",
        "omschrijving": "Voor onze servicedesk zoeken wij een klantgerichte ICT medewerker die gebruikers helpt bij ICT-problemen. Je beantwoordt vragen via telefoon, e-mail en chat en lost storingen op afstand op. Je werkt met een ticketsysteem en hebt ervaring met Windows 10 en Office 365.",
    },
    {
        "titel": "Machine Learning Engineer", "bedrijf_naam": "ASML",
        "bedrijf_sector": "ICT", "gemeente": "Eindhoven", "contract_type": "vast",
        "uren_per_week_min": 40, "uren_per_week_max": 40,
        "vereiste_opleiding": "wo", "vereiste_ervaring_jaren": 2,
        "vereiste_vaardigheden_raw": "Python, TensorFlow, PyTorch, MLOps, SQL, cloud, Git",
        "omschrijving": "ASML zoekt een Machine Learning Engineer om AI-modellen te bouwen voor kwaliteitscontrole in chipproductie. Je werkt in een multidisciplinair team van data scientists en software engineers. Wo-niveau in informatica of vergelijkbaar en ervaring met deep learning frameworks zijn vereist.",
    },
    # ADMINISTRATIE (5)
    {
        "titel": "Administratief Medewerker", "bedrijf_naam": "Randstad Nederland",
        "bedrijf_sector": "Administratie", "gemeente": "Den Haag", "contract_type": "tijdelijk",
        "uren_per_week_min": 24, "uren_per_week_max": 32,
        "vereiste_opleiding": "mbo", "vereiste_ervaring_jaren": 2,
        "vereiste_vaardigheden_raw": "Excel, Word, factuurverwerking, debiteurenbeheer, Exact, archiveren",
        "omschrijving": "Voor een klant in Den Haag zoeken wij een ervaren administratief medewerker. Je verwerkt inkomende facturen, beheert debiteuren en crediteuren en verzorgt de archivering. Je werkt met Exact Online en hebt goede Excel-kennis. Oog voor detail en proactieve werkhouding zijn essentieel.",
    },
    {
        "titel": "Controller", "bedrijf_naam": "Havenbedrijf Rotterdam",
        "bedrijf_sector": "Administratie", "gemeente": "Rotterdam", "contract_type": "vast",
        "uren_per_week_min": 36, "uren_per_week_max": 40,
        "vereiste_opleiding": "hbo", "vereiste_ervaring_jaren": 5,
        "vereiste_vaardigheden_raw": "financiële rapportage, budgettering, Excel, SAP, forecasting, management informatie",
        "omschrijving": "Het Havenbedrijf Rotterdam zoekt een Controller voor de afdeling Finance & Control. Je draagt zorg voor de maand- en kwartaalrapportages, het budgetteringsproces en de forecast. Je werkt nauw samen met het management en bent verantwoordelijk voor de financiële planning. SAP-kennis is vereist.",
    },
    {
        "titel": "HR Medewerker", "bedrijf_naam": "Albert Heijn",
        "bedrijf_sector": "Administratie", "gemeente": "Zaandam", "contract_type": "vast",
        "uren_per_week_min": 32, "uren_per_week_max": 40,
        "vereiste_opleiding": "hbo", "vereiste_ervaring_jaren": 2,
        "vereiste_vaardigheden_raw": "salarisadministratie, werving, Afas, HR-beleid, arbeidsrecht basis",
        "omschrijving": "Albert Heijn zoekt een HR Medewerker voor het HR-team op het hoofdkantoor in Zaandam. Je ondersteunt bij werving en selectie, verzorgt de salarisadministratie in AFAS en beantwoordt HR-vragen van medewerkers. Minimaal 2 jaar HR-ervaring en hbo HRM zijn vereist.",
    },
    {
        "titel": "Klantservicemedewerker", "bedrijf_naam": "Vodafone Nederland",
        "bedrijf_sector": "Administratie", "gemeente": "Amsterdam", "contract_type": "tijdelijk",
        "uren_per_week_min": 24, "uren_per_week_max": 36,
        "vereiste_opleiding": "mbo", "vereiste_ervaring_jaren": 1,
        "vereiste_vaardigheden_raw": "telefonie, e-mail, CRM, klachtenafhandeling, klantenservice",
        "omschrijving": "Voor het klantservicecentrum van Vodafone zoeken wij enthousiaste medewerkers. Je helpt klanten telefonisch en via e-mail met vragen over abonnementen, facturen en storingen. Je werkt met ons CRM-systeem en streeft naar maximale klanttevredenheid.",
    },
    {
        "titel": "Financieel Manager", "bedrijf_naam": "Philips Nederland",
        "bedrijf_sector": "Administratie", "gemeente": "Eindhoven", "contract_type": "vast",
        "uren_per_week_min": 40, "uren_per_week_max": 40,
        "vereiste_opleiding": "wo", "vereiste_ervaring_jaren": 8,
        "vereiste_vaardigheden_raw": "consolidatie, jaarrekening, IFRS, SAP, budgettering, management rapportage, leidinggeven",
        "omschrijving": "Philips zoekt een ervaren Financieel Manager voor haar Nederlandse operations. Je bent verantwoordelijk voor de financiële rapportage, budgettering en compliance. Je geeft leiding aan een team van 5 financieel specialisten en rapporteert aan de CFO. IFRS-kennis en SAP zijn vereist.",
    },
    # RETAIL (5)
    {
        "titel": "Verkoopmedewerker Supermarkt", "bedrijf_naam": "Lidl Nederland",
        "bedrijf_sector": "Retail", "gemeente": "Breda", "contract_type": "vast",
        "uren_per_week_min": 16, "uren_per_week_max": 28,
        "vereiste_opleiding": "vmbo", "vereiste_ervaring_jaren": 0,
        "vereiste_vaardigheden_raw": "kassa, klantenservice, schappenplan, voorraadbeheer",
        "omschrijving": "Lidl Nederland is op zoek naar verkoopmedewerkers voor vestigingen in de regio Breda. Je vult schappen bij, bedient de kassa en zorgt voor een nette winkel. Klantgerichtheid en teamwork staan bij ons centraal. Ervaring in de retail is een pré maar niet vereist.",
    },
    {
        "titel": "Filiaalmanager", "bedrijf_naam": "Hema",
        "bedrijf_sector": "Retail", "gemeente": "Utrecht", "contract_type": "vast",
        "uren_per_week_min": 36, "uren_per_week_max": 40,
        "vereiste_opleiding": "mbo", "vereiste_ervaring_jaren": 4,
        "vereiste_vaardigheden_raw": "personeelsplanning, omzetverantwoordelijkheid, klanttevredenheid, inkoop, kassabeheer",
        "omschrijving": "HEMA zoekt een gedreven Filiaalmanager voor één van haar winkels in Utrecht. Je bent eindverantwoordelijk voor de dagelijkse bedrijfsvoering, stuurt een team van 10-20 medewerkers aan en bewaakt de omzetdoelen. Minimaal 4 jaar werkervaring in retail en leidinggevende ervaring zijn vereist.",
    },
    {
        "titel": "Accountmanager Binnendienst", "bedrijf_naam": "Schneider Electric",
        "bedrijf_sector": "Retail", "gemeente": "Hoofddorp", "contract_type": "vast",
        "uren_per_week_min": 36, "uren_per_week_max": 40,
        "vereiste_opleiding": "mbo", "vereiste_ervaring_jaren": 2,
        "vereiste_vaardigheden_raw": "CRM, offertes, klantencontact, Excel, telefonische verkoop, relatiebeheer",
        "omschrijving": "Schneider Electric zoekt een commercieel gedreven Accountmanager Binnendienst. Je beheert een klantportfolio, stelt offertes op en onderhoudt klantrelaties via telefoon en e-mail. Je werkt met Salesforce CRM en hebt minimaal 2 jaar commerciële ervaring.",
    },
    {
        "titel": "Marketing Medewerker", "bedrijf_naam": "Bol.com",
        "bedrijf_sector": "Retail", "gemeente": "Utrecht", "contract_type": "vast",
        "uren_per_week_min": 32, "uren_per_week_max": 40,
        "vereiste_opleiding": "hbo", "vereiste_ervaring_jaren": 2,
        "vereiste_vaardigheden_raw": "social media, content creatie, Google Analytics, e-mailmarketing, campagnes, Canva",
        "omschrijving": "Bol.com zoekt een creatieve Marketing Medewerker voor het digitale marketingteam. Je ontwikkelt en uitvoert campagnes voor social media en e-mail, analyseert resultaten en optimaliseert content. Minimaal 2 jaar marketingervaring en kennis van Google Analytics zijn vereist.",
    },
    {
        "titel": "Communicatiemedewerker", "bedrijf_naam": "NS Nederlandse Spoorwegen",
        "bedrijf_sector": "Overheid", "gemeente": "Utrecht", "contract_type": "vast",
        "uren_per_week_min": 32, "uren_per_week_max": 40,
        "vereiste_opleiding": "hbo", "vereiste_ervaring_jaren": 2,
        "vereiste_vaardigheden_raw": "copywriting, social media, persberichten, interne communicatie, Canva, Adobe",
        "omschrijving": "NS zoekt een Communicatiemedewerker voor haar communicatieteam. Je schrijft teksten voor interne en externe kanalen, beheert sociale media en ondersteunt bij campagnes. Hbo Communicatie en minimaal 2 jaar communicatie-ervaring zijn vereist.",
    },
    # BOUW (5)
    {
        "titel": "Uitvoerder Bouw", "bedrijf_naam": "BAM Bouw en Techniek",
        "bedrijf_sector": "Bouw", "gemeente": "Amsterdam", "contract_type": "vast",
        "uren_per_week_min": 40, "uren_per_week_max": 40,
        "vereiste_opleiding": "mbo", "vereiste_ervaring_jaren": 5,
        "vereiste_vaardigheden_raw": "werkvoorbereiding, VCA, planning, kwaliteitscontrole, onderaannemers, AutoCAD",
        "omschrijving": "BAM Bouw en Techniek is op zoek naar een ervaren Uitvoerder voor woningbouwprojecten in de Randstad. Je bent verantwoordelijk voor de dagelijkse aansturing op de bouwplaats, de planning en de kwaliteitscontrole. Minimaal 5 jaar uitvoerdervaring en VCA-certificering zijn vereist.",
    },
    {
        "titel": "Elektromonteur Installatie", "bedrijf_naam": "Strukton Techniek",
        "bedrijf_sector": "Bouw", "gemeente": "Rotterdam", "contract_type": "vast",
        "uren_per_week_min": 40, "uren_per_week_max": 40,
        "vereiste_opleiding": "vmbo", "vereiste_ervaring_jaren": 3,
        "vereiste_vaardigheden_raw": "elektrische installaties, bekabeling, meterkast, VCA, NEN 3140",
        "omschrijving": "Strukton Techniek zoekt elektromonteurs voor elektrotechnische projecten bij bedrijven en overheidsinstellingen. Je monteert bekabeling, schakelkasten en verlichting en verzorgt keuring en oplevering. VCA en NEN 3140 zijn vereist. Rijbewijs B is noodzakelijk.",
    },
    {
        "titel": "Onderhoudsmonteur Industrie", "bedrijf_naam": "BASF Nederland",
        "bedrijf_sector": "Bouw", "gemeente": "Rotterdam", "contract_type": "vast",
        "uren_per_week_min": 40, "uren_per_week_max": 40,
        "vereiste_opleiding": "mbo", "vereiste_ervaring_jaren": 5,
        "vereiste_vaardigheden_raw": "preventief onderhoud, storingsanalyse, pneumatiek, hydrauliek, VCA, lassen MIG/MAG",
        "omschrijving": "BASF zoekt een ervaren Onderhoudsmonteur voor haar productielocatie in Rotterdam. Je voert preventief en correctief onderhoud uit aan mechanische en hydraulische installaties. Minimaal 5 jaar industrie-ervaring en VCA-certificering zijn vereist.",
    },
    {
        "titel": "Projectleider Infra", "bedrijf_naam": "Heijmans Infra",
        "bedrijf_sector": "Bouw", "gemeente": "Den Haag", "contract_type": "vast",
        "uren_per_week_min": 40, "uren_per_week_max": 40,
        "vereiste_opleiding": "hbo", "vereiste_ervaring_jaren": 5,
        "vereiste_vaardigheden_raw": "projectmanagement, aanbesteding, AutoCAD, RAW-bestek, planning, stakeholdermanagement",
        "omschrijving": "Heijmans Infra zoekt een Projectleider voor de realisatie van wegenbouw- en rioolprojecten in de regio Den Haag. Je leidt projecten van aanbesteding tot oplevering, bewaakt planning en budget en onderhoudt contacten met gemeenten. Hbo Civiele Techniek en 5 jaar PM-ervaring zijn vereist.",
    },
    {
        "titel": "Schilder", "bedrijf_naam": "Schildersbedrijf Van der Berg",
        "bedrijf_sector": "Bouw", "gemeente": "Haarlem", "contract_type": "vast",
        "uren_per_week_min": 36, "uren_per_week_max": 40,
        "vereiste_opleiding": "vmbo", "vereiste_ervaring_jaren": 3,
        "vereiste_vaardigheden_raw": "schilderen, pleisteren, behangen, spuittechnieken, VCA",
        "omschrijving": "Schildersbedrijf Van der Berg zoekt een ervaren schilder voor nieuwbouw- en renovatieprojecten. Je werkt zelfstandig en in teamverband aan woningen en kantoorpanden. MBO Schilder/afwerking en VCA zijn vereist. Rijbewijs B is een pré.",
    },
]


def maak_vacatures():
    vacatures = []
    for i, vac in enumerate(VACATURES[:30], start=1):
        vacature = {
            "job_id": f"J-{i:03d}",
            "titel": vac["titel"],
            "bedrijf_naam": vac["bedrijf_naam"],
            "bedrijf_sector": vac["bedrijf_sector"],
            "gemeente": vac["gemeente"],
            "contract_type": vac["contract_type"],
            "uren_per_week_min": vac["uren_per_week_min"],
            "uren_per_week_max": vac["uren_per_week_max"],
            "vereiste_opleiding": vac["vereiste_opleiding"],
            "vereiste_ervaring_jaren": vac["vereiste_ervaring_jaren"],
            "vereiste_vaardigheden_raw": vac["vereiste_vaardigheden_raw"],
            "omschrijving": vac["omschrijving"],
            "status": "actief",
        }
        vacatures.append(vacature)
    return vacatures


# ---------------------------------------------------------------------------
# BUILD AND WRITE DATAFRAMES
# ---------------------------------------------------------------------------

kandidaten = maak_kandidaten()
vacatures = maak_vacatures()

print(f"Gegenereerde kandidaten: {len(kandidaten)}")
print(f"Gegenereerde vacatures: {len(vacatures)}")

# Write candidates_raw
candidates_df = pd.DataFrame(kandidaten)
candidates_df["geboortejaar"] = candidates_df["geboortejaar"].astype(int)
candidates_df["werkervaring_jaren"] = candidates_df["werkervaring_jaren"].astype(float)
candidates_df["mobiliteitskm"] = candidates_df["mobiliteitskm"].astype(int)

candidates_raw = dataiku.Dataset("candidates_raw")
candidates_raw.write_with_schema(candidates_df)
print(f"candidates_raw: {len(candidates_df)} rijen geschreven.")

# Write job_postings_raw
jobs_df = pd.DataFrame(vacatures)
jobs_df["uren_per_week_min"] = jobs_df["uren_per_week_min"].astype(int)
jobs_df["uren_per_week_max"] = jobs_df["uren_per_week_max"].astype(int)
jobs_df["vereiste_ervaring_jaren"] = jobs_df["vereiste_ervaring_jaren"].astype(int)

job_postings_raw = dataiku.Dataset("job_postings_raw")
job_postings_raw.write_with_schema(jobs_df)
print(f"job_postings_raw: {len(jobs_df)} rijen geschreven.")
